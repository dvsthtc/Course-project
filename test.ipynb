# %%
from user_test import *
# Out:
# Direct task of magnetometry for simple figures
# Available figures:
# 1.uniformly magnetized sphere
# 2.Horizonlal cylinder
# 3.Cylinder with slanting magnetization
# 4.Restricted vertical stock
# 5.Deep stock
# Enter the number of desired figure: 5
# Enter the h value: 50
# Enter the r value: 40
# Enter the J value: 0.21
#             Ha, nTl  Ha,gamma  Za, gamma       Za, nTl
# -800   -8745.168202 -0.087452   0.005466  5.465730e+02
# -400  -34376.987907 -0.343770   0.042971  4.297123e+03
# -200 -128509.276520 -1.285093   0.321273  3.212732e+04
# -100 -402830.975937 -4.028310   2.014155  2.014155e+05
# -80  -536405.046503 -5.364050   3.352532  3.352532e+05
# -60  -708996.964646 -7.089970   5.908308  5.908308e+05
# -40  -857772.431917 -8.577724  10.722155  1.072216e+06
# -20  -720976.114151 -7.209761  18.024403  1.802440e+06
# -10  -424646.800325 -4.246468  21.232340  2.123234e+06
# -5   -221853.256873 -2.218533  22.185326  2.218533e+06
# ...
